# %%
# import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\senay\Desktop\Misra Turp\NYC_Jobs.csv")
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339             PUBLIC HEALTH NURSE  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL          NYC HOUSING AUTHORITY
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                          NaN
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To
# 0            84252.0          84252.0
# 1            82884.0         116391.0
# 2           105000.0         125000.0
# ...

# %%
data.columns
# Out:
# Index(['Job ID', 'Civil Service Title', 'Agency', 'Posting Type',
#        'Job Category', 'Salary Range From', 'Salary Range To'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Job ID               3773 non-null   int64
#  1   Civil Service Title  3773 non-null   object
#  2   Agency               3773 non-null   object
#  3   Posting Type         3773 non-null   object
#  4   Job Category         3770 non-null   object
#  5   Salary Range From    3773 non-null   float64
#  6   Salary Range To      3773 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 206.5+ KB

# %%
data.describe()
# Out:
#               Job ID  Salary Range From  Salary Range To
# count    3773.000000        3773.000000      3773.000000
# mean   500493.408693       57657.939466     79660.249595
# std     48518.942211       36629.729583     51101.248638
# min     87990.000000           0.000000        15.000000
# 25%    496634.000000       40017.000000     54228.000000
# 50%    518535.000000       58700.000000     80000.000000
# 75%    524405.000000       75000.000000    109409.000000
# max    528532.000000      250000.000000    265000.000000

# %%
data.shape
# Out:
# (3773, 7)

# %%
data['Salary Range From'].apply(np.sqrt)
# Out:
# 0       290.261951
# 1       287.895814
# 2       324.037035
# 3       295.301541
# 4       241.762280
#            ...
# 3768    292.183162
# 3769    273.221522
# 3770    316.227766
# 3771    205.640463
# 3772    249.793915
# Name: Salary Range From, Length: 3773, dtype: float64

# %%
data[['Salary Range From', 'Salary Range To']].apply(np.sqrt)
# Out:
#       Salary Range From  Salary Range To
# 0            290.261951       290.261951
# 1            287.895814       341.161252
# 2            324.037035       353.553391
# 3            295.301541       362.798842
# 4            241.762280       259.260487
# ...                 ...              ...
# 3768         292.183162       346.241245
# 3769         273.221522       292.996587
# 3770         316.227766       339.116499
# 3771         205.640463       243.721152
# 3772         249.793915       267.874971
#
# [3773 rows x 2 columns]

# %%
data[['Salary Range From', 'Salary Range To']].apply('mean')
# Out:
# Salary Range From    57657.939466
# Salary Range To      79660.249595
# dtype: float64

# %%
data[['Salary Range From', 'Salary Range To']].apply(np.mean)
# Out:
# Salary Range From    57657.939466
# Salary Range To      79660.249595
# dtype: float64

# %%
#each column
data[['Salary Range From', 'Salary Range To']].apply(np.mean, axis = 0)
# Out:
# Salary Range From    57657.939466
# Salary Range To      79660.249595
# dtype: float64

# %%
#each row
data[['Salary Range From', 'Salary Range To']].apply(np.mean, axis = 1)
# Out:
# 0        84252.0
# 1        99637.5
# 2       115000.0
# 3       109413.0
# 4        62832.5
#           ...
# 3768    102627.0
# 3769     80248.5
# 3770    107500.0
# 3771     50844.0
# 3772     67077.0
# Length: 3773, dtype: float64

# %%
data['Salary Avg'] = data[['Salary Range From', 'Salary Range To']].apply(np.mean, axis = 1)

# %%
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339             PUBLIC HEALTH NURSE  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL          NYC HOUSING AUTHORITY
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                          NaN
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To  Salary Avg
# 0            84252.0          84252.0     84252.0
# 1            82884.0         116391.0     99637.5
# ...

# %%
data['Civil Service Title']
# Out:
# 0                  PUBLIC HEALTH NURSE
# 1              CERT IT DEVELOPER (APP)
# 2             EXECUTIVE AGENCY COUNSEL
# 3       CERTIFIED IT ADMINISTRATOR (LA
# 4       ASSOCIATE HUMAN RIGHTS SPECIAL
#                      ...
# 3768    CERTIFIED IT ADMINISTRATOR (LA
# 3769     ASSOCIATE HOUSING DEVELOPMENT
# 3770               SENIOR IT ARCHITECT
# 3771                         ECONOMIST
# 3772           AGENCY ATTORNEY INTERNE
# Name: Civil Service Title, Length: 3773, dtype: object

# %%
#create function to capitalize civil service title

# %%
def capitalize_position(title): 
    title_lower = title.lower()
    title_final=title_lower.capitalize()
    return title_final

# %%
data['Civil Service Title'].apply(capitalize_position)
# Out:
# 0                  Public health nurse
# 1              Cert it developer (app)
# 2             Executive agency counsel
# 3       Certified it administrator (la
# 4       Associate human rights special
#                      ...
# 3768    Certified it administrator (la
# 3769     Associate housing development
# 3770               Senior it architect
# 3771                         Economist
# 3772           Agency attorney interne
# Name: Civil Service Title, Length: 3773, dtype: object

# %%
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339             PUBLIC HEALTH NURSE  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL          NYC HOUSING AUTHORITY
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                          NaN
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To  Salary Avg
# 0            84252.0          84252.0     84252.0
# 1            82884.0         116391.0     99637.5
# ...

# %%
#apply lambda function to capitalize civil service title

# %%
data['Civil Service Title'].apply(lambda x: x.lower().capitalize())
# Out:
# 0                  Public health nurse
# 1              Cert it developer (app)
# 2             Executive agency counsel
# 3       Certified it administrator (la
# 4       Associate human rights special
#                      ...
# 3768    Certified it administrator (la
# 3769     Associate housing development
# 3770               Senior it architect
# 3771                         Economist
# 3772           Agency attorney interne
# Name: Civil Service Title, Length: 3773, dtype: object

# %%
data['Agency'].apply(lambda x: x.lower().capitalize())
# Out:
# 0        Dept of health/mental hygiene
# 1         Nyc employees retirement sys
# 2                Nyc housing authority
# 3         Nyc employees retirement sys
# 4              Human rights commission
#                      ...
# 3768      Nyc employees retirement sys
# 3769    Housing preservation & dvlpmnt
# 3770        Financial info svcs agency
# 3771     Dept of health/mental hygiene
# 3772           Human rights commission
# Name: Agency, Length: 3773, dtype: object

# %%
data.apply(lambda x: x['Civil Service Title'].lower().capitalize(), axis=1)
# Out:
# 0                  Public health nurse
# 1              Cert it developer (app)
# 2             Executive agency counsel
# 3       Certified it administrator (la
# 4       Associate human rights special
#                      ...
# 3768    Certified it administrator (la
# 3769     Associate housing development
# 3770               Senior it architect
# 3771                         Economist
# 3772           Agency attorney interne
# Length: 3773, dtype: object

# %%
#use lambda to put all columnns into a list

# %%
data.apply(lambda x: x.to_list(), axis = 1)
# Out:
# 0       [424339, PUBLIC HEALTH NURSE, DEPT OF HEALTH/M...
# 1       [379094, CERT IT DEVELOPER (APP), NYC EMPLOYEE...
# 2       [520417, EXECUTIVE AGENCY COUNSEL, NYC HOUSING...
# 3       [233549, CERTIFIED IT ADMINISTRATOR (LA, NYC E...
# 4       [510256, ASSOCIATE HUMAN RIGHTS SPECIAL, HUMAN...
#                               ...
# 3768    [457839, CERTIFIED IT ADMINISTRATOR (LA, NYC E...
# 3769    [527141, ASSOCIATE HOUSING DEVELOPMENT, HOUSIN...
# 3770    [509443, SENIOR IT ARCHITECT, FINANCIAL INFO S...
# 3771    [352367, ECONOMIST, DEPT OF HEALTH/MENTAL HYGI...
# 3772    [478739, AGENCY ATTORNEY INTERNE, HUMAN RIGHTS...
# Length: 3773, dtype: object

# %%
# use result_type to expand list 
data.apply(lambda x: x.to_list(), axis = 1, result_type='expand')
# Out:
#            0                               1                               2  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL           NYC HOUSING AUTHORITY
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
# use result_type to broadcast to expand and keep column names 
data.apply(lambda x: x.to_list(), axis = 1, result_type='broadcast')
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL           NYC HOUSING AUTHORITY
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...
