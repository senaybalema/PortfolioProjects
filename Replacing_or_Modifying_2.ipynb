# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'C:\Users\senay\Desktop\Misra Turp\NYC_Jobs.csv')
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339             PUBLIC HEALTH NURSE  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL          NYC HOUSING AUTHORITY
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                          NaN
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To
# 0            84252.0          84252.0
# 1            82884.0         116391.0
# 2           105000.0         125000.0
# ...

# %% [markdown]
# # fillna()

# %%
data['Job Category'].fillna('Unavailable').head()
# Out:
# 0                                         Health
# 1                                    Unavailable
# 2                                  Legal Affairs
# 3    Information Technology & Telecommunications
# 4      Constituent Services & Community Programs
# Name: Job Category, dtype: object

# %%
data = data.fillna('Legal Affairs')

# %%
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339             PUBLIC HEALTH NURSE  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL          NYC HOUSING AUTHORITY
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                Legal Affairs
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To
# 0            84252.0          84252.0
# 1            82884.0         116391.0
# 2           105000.0         125000.0
# ...

# %% [markdown]
# # replace

# %%
data.replace('NYC HOUSING AUTHORITY', 'NYC AUTHORITY FOR HOUSING',inplace=True)

# %%
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
data.replace('PUBLIC HEALTH NURSE','PUBLIC HEALTH NURSING',inplace=True)
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339           PUBLIC HEALTH NURSING  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL      NYC AUTHORITY FOR HOUSING
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                Legal Affairs
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To
# 0            84252.0          84252.0
# 1            82884.0         116391.0
# 2           105000.0         125000.0
# ...

# %% [markdown]
# # loc

# %%
data.loc[data['Posting Type']== 'External', "Posting Type"]= 1
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339           PUBLIC HEALTH NURSING   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
data.loc[data['Job Category']=='Health', 'Job Category'] = 'Med'
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339           PUBLIC HEALTH NURSING   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %% [markdown]
# # at

# %%
data.at[data['Job Category']== 'Health', "Job Category"]= 'Health Dept.'
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
data.at[data['Civil Service Title'] == 'CERT IT DEVELOPER (APP)','Civil Service Title' ] = 'IT APP DEV'
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339           PUBLIC HEALTH NURSING   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094                      IT APP DEV    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
data.loc[3, 'Job Category'] = 'ITT'
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339           PUBLIC HEALTH NURSING   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094                      IT APP DEV    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
data.loc[1, 'Civil Service Title'] = 'CERT IT DEVELOPER (APP)'
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339           PUBLIC HEALTH NURSING   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %% [markdown]
# # np

# %%
data['Financial_Boolean']= np.where(data['Agency']=='FINANCIAL INFO SVCS AGENCY',True,False)
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
np.where(data['Civil Service Title'] =='SENIOR IT ARCHITECT',True,False)
# Out:
# array([False, False, False, ...,  True, False, False])

# %% [markdown]
# # mask

# %%
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339           PUBLIC HEALTH NURSING  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL      NYC AUTHORITY FOR HOUSING
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                               Job Category  Salary Range From  \
# 0            1                                        Med            84252.0
# 1            1                              Legal Affairs            82884.0
# 2            1                              Legal Affairs           105000.0
# 3            1                                        ITT            87203.0
# 4            1  Constituent Services & Community Programs            58449.0
#
#    Salary Range To
# 0          84252.0
# 1         116391.0
# ...

# %%
data['Agency'].mask(data['Civil Service Title']=='PUBLIC HEALTH NURSING',0)
# Out:
# 0                                    0
# 1         NYC EMPLOYEES RETIREMENT SYS
# 2            NYC AUTHORITY FOR HOUSING
# 3         NYC EMPLOYEES RETIREMENT SYS
# 4              HUMAN RIGHTS COMMISSION
#                      ...
# 3768      NYC EMPLOYEES RETIREMENT SYS
# 3769    HOUSING PRESERVATION & DVLPMNT
# 3770        FINANCIAL INFO SVCS AGENCY
# 3771     DEPT OF HEALTH/MENTAL HYGIENE
# 3772           HUMAN RIGHTS COMMISSION
# Name: Agency, Length: 3773, dtype: object

# %%
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339           PUBLIC HEALTH NURSING  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL      NYC AUTHORITY FOR HOUSING
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                               Job Category  Salary Range From  \
# 0            1                                        Med            84252.0
# 1            1                              Legal Affairs            82884.0
# 2            1                              Legal Affairs           105000.0
# 3            1                                        ITT            87203.0
# 4            1  Constituent Services & Community Programs            58449.0
#
#    Salary Range To
# 0          84252.0
# 1         116391.0
# ...

# %%
data['Job Category'].mask(data['Agency']=='HUMAN RIGHTS COMMISSION','CSPS')
# Out:
# 0                                         Med
# 1                               Legal Affairs
# 2                               Legal Affairs
# 3                                         ITT
# 4                                        CSPS
#                         ...
# 3768            Technology, Data & Innovation
# 3769    Engineering, Architecture, & Planning
# 3770            Technology, Data & Innovation
# 3771       Finance, Accounting, & Procurement
# 3772                                     CSPS
# Name: Job Category, Length: 3773, dtype: object

# %% [markdown]
# # cut

# %%
data['salary lower limit ranges']=pd.cut(data['Salary Range From'],3)
data
# Out:
#       Job ID             Civil Service Title                          Agency  \
# 0     424339             PUBLIC HEALTH NURSE   DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094         CERT IT DEVELOPER (APP)    NYC EMPLOYEES RETIREMENT SYS
# 2     520417        EXECUTIVE AGENCY COUNSEL       NYC AUTHORITY FOR HOUSING
# 3     233549  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 4     510256  ASSOCIATE HUMAN RIGHTS SPECIAL         HUMAN RIGHTS COMMISSION
# ...      ...                             ...                             ...
# 3768  457839  CERTIFIED IT ADMINISTRATOR (LA    NYC EMPLOYEES RETIREMENT SYS
# 3769  527141   ASSOCIATE HOUSING DEVELOPMENT  HOUSING PRESERVATION & DVLPMNT
# 3770  509443             SENIOR IT ARCHITECT      FINANCIAL INFO SVCS AGENCY
# 3771  352367                       ECONOMIST   DEPT OF HEALTH/MENTAL HYGIENE
# 3772  478739         AGENCY ATTORNEY INTERNE         HUMAN RIGHTS COMMISSION
#
# ...

# %%
pd.cut(data['Salary Range To'],5)
# Out:
# 0        (53012.0, 106009.0]
# 1       (106009.0, 159006.0]
# 2       (106009.0, 159006.0]
# 3       (106009.0, 159006.0]
# 4        (53012.0, 106009.0]
#                 ...
# 3768    (106009.0, 159006.0]
# 3769     (53012.0, 106009.0]
# 3770    (106009.0, 159006.0]
# 3771     (53012.0, 106009.0]
# 3772     (53012.0, 106009.0]
# Name: Salary Range To, Length: 3773, dtype: category
# Categories (5, interval[float64, right]): [(-249.985, 53012.0] < (53012.0, 106009.0] < (106009.0, 159006.0] < (159006.0, 212003.0] < (212003.0, 265000.0]]

# %% [markdown]
# # update

# %%
df = pd.DataFrame({ 'A': [1,2,3],
                   'B': [400,500,600]})
new_df = pd.DataFrame({ 'B': [4,5,6],
                   'C': [7,8,9]})

# %%
df
# Out:
#    A    B
# 0  1  400
# 1  2  500
# 2  3  600

# %%
new_df
# Out:
#    B  C
# 0  4  7
# 1  5  8
# 2  6  9

# %%
df.update(new_df)
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
