# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
#Getting Data
data = pd.read_excel(r"C:\Users\senay\Downloads\SBA_DATA\NAICS\Table of Size Standards_Effective July 14 2022.xlsx", sheet_name = 'Table of Size Standards_Effecti')
data
# Out:
#                           NAICS Codes  \
# 0                                 NaN
# 1     Subsector 111 – Crop Production
# 2                              111110
# 3                              111120
# 4                              111130
# ...                               ...
# 1144                           813930
# 1145                           813940
# 1146                           813990
# 1147                              NaN
# 1148                              NaN
#
#                              NAICS Industry Description  \
# 0     Sector 11 – Agriculture, Forestry, Fishing and...
# 1                                                   NaN
# 2                                       Soybean Farming
# 3                      Oilseed (except Soybean) Farming
# 4                              Dry Pea and Bean Farming
# ...                                                 ...
# 1144      Labor Unions and Similar Labor Organizations
# 1145                            Political Organizations
# 1146  Other Similar Organizations (except Business, ...
# 1147                  Sector 92 – Public Administration
# 1148  (Small business size standards are not establi...
#
#      Size standards \nin millions of dollars  \
# 0                                        NaN
# 1                                        NaN
# 2                                          2
# 3                                          2
# 4                                        2.5
# ...                                      ...
# 1144                                    14.5
# 1145                                    12.5
# 1146                                      12
# 1147                                     NaN
# 1148                                     NaN
#
#       Size standards in number of employees        Footnotes
# 0                                       NaN              NaN
# 1                                       NaN              NaN
# 2                                       NaN              NaN
# 3                                       NaN              NaN
# 4                                       NaN              NaN
# ...                                     ...              ...
# 1144                                    NaN              NaN
# 1145                                    NaN              NaN
# 1146                                    NaN              NaN
# 1147                                    NaN  See footnote 17
# 1148                                    NaN              NaN
#
# [1149 rows x 5 columns]

# %%
data.head()
# Out:
#                        NAICS Codes  \
# 0                              NaN
# 1  Subsector 111 – Crop Production
# 2                           111110
# 3                           111120
# 4                           111130
#
#                           NAICS Industry Description  \
# 0  Sector 11 – Agriculture, Forestry, Fishing and...
# 1                                                NaN
# 2                                    Soybean Farming
# 3                   Oilseed (except Soybean) Farming
# 4                           Dry Pea and Bean Farming
#
#   Size standards \nin millions of dollars  \
# 0                                     NaN
# 1                                     NaN
# 2                                       2
# 3                                       2
# 4                                     2.5
#
#    Size standards in number of employees Footnotes
# 0                                    NaN       NaN
# 1                                    NaN       NaN
# 2                                    NaN       NaN
# 3                                    NaN       NaN
# 4                                    NaN       NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149 entries, 0 to 1148
# Data columns (total 5 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   NAICS Codes                             1126 non-null   object
#  1   NAICS Industry Description              1060 non-null   object
#  2   Size standards
# in millions of dollars  532 non-null    object
#  3   Size standards in number of employees   505 non-null    float64
#  4   Footnotes                               39 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 45.0+ KB

# %%
#Checking for null
data.isnull().sum()
# Out:
# NAICS Codes                                  23
# NAICS Industry Description                   89
# Size standards \nin millions of dollars     617
# Size standards in number of employees       644
# Footnotes                                  1110
# dtype: int64

# %%
#selecting only the relevant records 
data = data[data['NAICS Codes'].isnull()]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 1148
# Data columns (total 5 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   NAICS Codes                             0 non-null      object
#  1   NAICS Industry Description              23 non-null     object
#  2   Size standards
# in millions of dollars  0 non-null      object
#  3   Size standards in number of employees   0 non-null      float64
#  4   Footnotes                               1 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 1.1+ KB

# %%
data.head()
# Out:
#     NAICS Codes                         NAICS Industry Description  \
# 0           NaN  Sector 11 – Agriculture, Forestry, Fishing and...
# 71          NaN  Sector 21 – Mining, Quarrying, and Oil and Gas...
# 103         NaN                              Sector 22 – Utilities
# 119         NaN                           Sector 23 – Construction
# 156         NaN                     Sector 31 – 33 – Manufacturing
#
#     Size standards \nin millions of dollars  \
# 0                                       NaN
# 71                                      NaN
# 103                                     NaN
# 119                                     NaN
# 156                                     NaN
#
#      Size standards in number of employees Footnotes
# 0                                      NaN       NaN
# 71                                     NaN       NaN
# 103                                    NaN       NaN
# 119                                    NaN       NaN
# 156                                    NaN       NaN

# %%
data['LookupCodes'] = data['NAICS Industry Description'].str.slice(start = 7, stop = 9 )

# %%
data.head()
# Out:
#     NAICS Codes                         NAICS Industry Description  \
# 0           NaN  Sector 11 – Agriculture, Forestry, Fishing and...
# 71          NaN  Sector 21 – Mining, Quarrying, and Oil and Gas...
# 103         NaN                              Sector 22 – Utilities
# 119         NaN                           Sector 23 – Construction
# 156         NaN                     Sector 31 – 33 – Manufacturing
#
#     Size standards \nin millions of dollars  \
# 0                                       NaN
# 71                                      NaN
# 103                                     NaN
# 119                                     NaN
# 156                                     NaN
#
#      Size standards in number of employees Footnotes LookupCodes
# 0                                      NaN       NaN          11
# 71                                     NaN       NaN          21
# 103                                    NaN       NaN          22
# 119                                    NaN       NaN          23
# 156                                    NaN       NaN          31

# %%
data['NAICS Industry Description'].str.len()
# Out:
# 0        54
# 71       57
# 103      21
# 119      24
# 156      30
# 538      27
# 539     537
# 614      29
# 615     537
# 694      47
# 764      23
# 802      33
# 847      46
# 875      59
# 932      51
# 936      84
# 984      32
# 1004     45
# 1048     46
# 1077     43
# 1095     26
# 1147     33
# 1148    284
# Name: NAICS Industry Description, dtype: int64

# %%
data['Sector'] = data['NAICS Industry Description'].str.slice(start = 12, stop = 538)
data.head()
# Out:
#     NAICS Codes                         NAICS Industry Description  \
# 0           NaN  Sector 11 – Agriculture, Forestry, Fishing and...
# 71          NaN  Sector 21 – Mining, Quarrying, and Oil and Gas...
# 103         NaN                              Sector 22 – Utilities
# 119         NaN                           Sector 23 – Construction
# 156         NaN                     Sector 31 – 33 – Manufacturing
#
#     Size standards \nin millions of dollars  \
# 0                                       NaN
# 71                                      NaN
# 103                                     NaN
# 119                                     NaN
# 156                                     NaN
#
#      Size standards in number of employees Footnotes LookupCodes  \
# 0                                      NaN       NaN          11
# 71                                     NaN       NaN          21
# 103                                    NaN       NaN          22
# 119                                    NaN       NaN          23
# 156                                    NaN       NaN          31
#
#                                             Sector
# 0       Agriculture, Forestry, Fishing and Hunting
# 71   Mining, Quarrying, and Oil and Gas Extraction
# 103                                      Utilities
# 119                                   Construction
# 156                             33 – Manufacturing

# %%
data = data[['NAICS Industry Description', 'LookupCodes', 'Sector']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 1147
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   NAICS Industry Description  20 non-null     object
#  1   LookupCodes                 20 non-null     object
#  2   Sector                      20 non-null     object
# dtypes: object(3)
# memory usage: 640.0+ bytes

# %%
data
# Out:
#      NAICS Codes                         NAICS Industry Description  \
# 0            NaN  Sector 11 – Agriculture, Forestry, Fishing and...
# 71           NaN  Sector 21 – Mining, Quarrying, and Oil and Gas...
# 103          NaN                              Sector 22 – Utilities
# 119          NaN                           Sector 23 – Construction
# 156          NaN                     Sector 31 – 33 – Manufacturing
# 538          NaN                        Sector 42 – Wholesale Trade
# 539          NaN  (These NAICS codes shall not be used to classi...
# 614          NaN                      Sector 44 - 45 – Retail Trade
# 615          NaN  (These NAICS codes shall not be used to classi...
# 694          NaN    Sector 48 - 49 – Transportation and Warehousing
# 764          NaN                            Sector 51 – Information
# 802          NaN                  Sector 52 – Finance and Insurance
# 847          NaN     Sector 53 – Real Estate and Rental and Leasing
# 875          NaN  Sector 54 – Professional, Scientific and Techn...
# 932          NaN  Sector 55 – Management of Companies and Enterp...
# 936          NaN  Sector 56 – Administrative and Support and Was...
# 984          NaN                   Sector 61 – Educational Services
# 1004         NaN      Sector 62 – Health Care and Social Assistance
# 1048         NaN     Sector 71 – Arts, Entertainment and Recreation
# 1077         NaN        Sector 72 – Accommodation and Food Services
# 1095         NaN                         Sector 81 – Other Services
# 1147         NaN                  Sector 92 – Public Administration
# 1148         NaN  (Small business size standards are not establi...
#
#      Size standards \nin millions of dollars  \
# 0                                        NaN
# 71                                       NaN
# 103                                      NaN
# 119                                      NaN
# 156                                      NaN
# 538                                      NaN
# 539                                      NaN
# 614                                      NaN
# 615                                      NaN
# 694                                      NaN
# 764                                      NaN
# 802                                      NaN
# 847                                      NaN
# 875                                      NaN
# 932                                      NaN
# 936                                      NaN
# 984                                      NaN
# 1004                                     NaN
# 1048                                     NaN
# 1077                                     NaN
# 1095                                     NaN
# 1147                                     NaN
# 1148                                     NaN
#
#       Size standards in number of employees        Footnotes LookupCodes  \
# 0                                       NaN              NaN          11
# 71                                      NaN              NaN          21
# 103                                     NaN              NaN          22
# 119                                     NaN              NaN          23
# 156                                     NaN              NaN          31
# 538                                     NaN              NaN          42
# 539                                     NaN              NaN          NA
# 614                                     NaN              NaN          44
# 615                                     NaN              NaN          NA
# 694                                     NaN              NaN          48
# 764                                     NaN              NaN          51
# 802                                     NaN              NaN          52
# 847                                     NaN              NaN          53
# 875                                     NaN              NaN          54
# 932                                     NaN              NaN          55
# 936                                     NaN              NaN          56
# 984                                     NaN              NaN          61
# 1004                                    NaN              NaN          62
# 1048                                    NaN              NaN          71
# 1077                                    NaN              NaN          72
# 1095                                    NaN              NaN          81
# 1147                                    NaN  See footnote 17          92
# 1148                                    NaN              NaN          bu
#
#                                                  Sector
# 0            Agriculture, Forestry, Fishing and Hunting
# 71        Mining, Quarrying, and Oil and Gas Extraction
# 103                                           Utilities
# 119                                        Construction
# 156                                  33 – Manufacturing
# 538                                     Wholesale Trade
# 539    codes shall not be used to classify Governmen...
# 614                                   45 – Retail Trade
# 615    codes shall not be used to classify Governmen...
# 694                 49 – Transportation and Warehousing
# 764                                         Information
# 802                               Finance and Insurance
# 847                  Real Estate and Rental and Leasing
# 875     Professional, Scientific and Technical Services
# 932             Management of Companies and Enterprises
# 936   Administrative and Support and Waste Managemen...
# 984                                Educational Services
# 1004                  Health Care and Social Assistance
# 1048                 Arts, Entertainment and Recreation
# 1077                    Accommodation and Food Services
# 1095                                     Other Services
# 1147                              Public Administration
# 1148  ess size standards are not established for thi...

# %%
data = data[data['LookupCodes'].str.isnumeric()]

# %%
data
# Out:
#                              NAICS Industry Description LookupCodes  \
# 0     Sector 11 – Agriculture, Forestry, Fishing and...          11
# 71    Sector 21 – Mining, Quarrying, and Oil and Gas...          21
# 103                               Sector 22 – Utilities          22
# 119                            Sector 23 – Construction          23
# 156                      Sector 31 – 33 – Manufacturing          31
# 538                         Sector 42 – Wholesale Trade          42
# 614                       Sector 44 - 45 – Retail Trade          44
# 694     Sector 48 - 49 – Transportation and Warehousing          48
# 764                             Sector 51 – Information          51
# 802                   Sector 52 – Finance and Insurance          52
# 847      Sector 53 – Real Estate and Rental and Leasing          53
# 875   Sector 54 – Professional, Scientific and Techn...          54
# 932   Sector 55 – Management of Companies and Enterp...          55
# 936   Sector 56 – Administrative and Support and Was...          56
# 984                    Sector 61 – Educational Services          61
# 1004      Sector 62 – Health Care and Social Assistance          62
# 1048     Sector 71 – Arts, Entertainment and Recreation          71
# 1077        Sector 72 – Accommodation and Food Services          72
# 1095                         Sector 81 – Other Services          81
# 1147                  Sector 92 – Public Administration          92
#
#                                                  Sector
# 0            Agriculture, Forestry, Fishing and Hunting
# 71        Mining, Quarrying, and Oil and Gas Extraction
# 103                                           Utilities
# 119                                        Construction
# 156                                  33 – Manufacturing
# 538                                     Wholesale Trade
# 614                                   45 – Retail Trade
# 694                 49 – Transportation and Warehousing
# 764                                         Information
# 802                               Finance and Insurance
# 847                  Real Estate and Rental and Leasing
# 875     Professional, Scientific and Technical Services
# 932             Management of Companies and Enterprises
# 936   Administrative and Support and Waste Managemen...
# 984                                Educational Services
# 1004                  Health Care and Social Assistance
# 1048                 Arts, Entertainment and Recreation
# 1077                    Accommodation and Food Services
# 1095                                     Other Services
# 1147                              Public Administration

# %%
#Replacing some values in sector
data.loc[data['Sector'] == '33 - Manufacturing ','Sector']='Manufacturing'
# Out:
# C:\Users\senay\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
data
# Out:
#      NAICS Codes                         NAICS Industry Description  \
# 0            NaN  Sector 11 – Agriculture, Forestry, Fishing and...
# 71           NaN  Sector 21 – Mining, Quarrying, and Oil and Gas...
# 103          NaN                              Sector 22 – Utilities
# 119          NaN                           Sector 23 – Construction
# 156          NaN                     Sector 31 – 33 – Manufacturing
# 538          NaN                        Sector 42 – Wholesale Trade
# 614          NaN                      Sector 44 - 45 – Retail Trade
# 694          NaN    Sector 48 - 49 – Transportation and Warehousing
# 764          NaN                            Sector 51 – Information
# 802          NaN                  Sector 52 – Finance and Insurance
# 847          NaN     Sector 53 – Real Estate and Rental and Leasing
# 875          NaN  Sector 54 – Professional, Scientific and Techn...
# 932          NaN  Sector 55 – Management of Companies and Enterp...
# 936          NaN  Sector 56 – Administrative and Support and Was...
# 984          NaN                   Sector 61 – Educational Services
# 1004         NaN      Sector 62 – Health Care and Social Assistance
# 1048         NaN     Sector 71 – Arts, Entertainment and Recreation
# 1077         NaN        Sector 72 – Accommodation and Food Services
# 1095         NaN                         Sector 81 – Other Services
# 1147         NaN                  Sector 92 – Public Administration
#
#      Size standards \nin millions of dollars  \
# 0                                        NaN
# 71                                       NaN
# 103                                      NaN
# 119                                      NaN
# 156                                      NaN
# 538                                      NaN
# 614                                      NaN
# 694                                      NaN
# 764                                      NaN
# 802                                      NaN
# 847                                      NaN
# 875                                      NaN
# 932                                      NaN
# 936                                      NaN
# 984                                      NaN
# 1004                                     NaN
# 1048                                     NaN
# 1077                                     NaN
# 1095                                     NaN
# 1147                                     NaN
#
#       Size standards in number of employees        Footnotes LookupCodes  \
# 0                                       NaN              NaN          11
# 71                                      NaN              NaN          21
# 103                                     NaN              NaN          22
# 119                                     NaN              NaN          23
# 156                                     NaN              NaN          31
# 538                                     NaN              NaN          42
# 614                                     NaN              NaN          44
# 694                                     NaN              NaN          48
# 764                                     NaN              NaN          51
# 802                                     NaN              NaN          52
# 847                                     NaN              NaN          53
# 875                                     NaN              NaN          54
# 932                                     NaN              NaN          55
# 936                                     NaN              NaN          56
# 984                                     NaN              NaN          61
# 1004                                    NaN              NaN          62
# 1048                                    NaN              NaN          71
# 1077                                    NaN              NaN          72
# 1095                                    NaN              NaN          81
# 1147                                    NaN  See footnote 17          92
#
#                                                  Sector
# 0            Agriculture, Forestry, Fishing and Hunting
# 71        Mining, Quarrying, and Oil and Gas Extraction
# 103                                           Utilities
# 119                                        Construction
# 156                                  33 – Manufacturing
# 538                                     Wholesale Trade
# 614                                   45 – Retail Trade
# 694                 49 – Transportation and Warehousing
# 764                                         Information
# 802                               Finance and Insurance
# 847                  Real Estate and Rental and Leasing
# 875     Professional, Scientific and Technical Services
# 932             Management of Companies and Enterprises
# 936   Administrative and Support and Waste Managemen...
# 984                                Educational Services
# 1004                  Health Care and Social Assistance
# 1048                 Arts, Entertainment and Recreation
# 1077                    Accommodation and Food Services
# 1095                                     Other Services
# 1147                              Public Administration

# %%
data['Sector'] = np.where(data['Sector']=='45 – Retail Trade','Retail Trade',data['Sector'])
data['Sector'] = np.where(data['Sector']=='49 – Transportation and Warehousing','Transportation and Warehousing',data['Sector'])
data['Sector'] = np.where(data['Sector']=='33 – Manufacturing','Manufacturing',data['Sector'])

# %%
data
# Out:
#                              NAICS Industry Description LookupCodes  \
# 0     Sector 11 – Agriculture, Forestry, Fishing and...          11
# 71    Sector 21 – Mining, Quarrying, and Oil and Gas...          21
# 103                               Sector 22 – Utilities          22
# 119                            Sector 23 – Construction          23
# 156                      Sector 31 – 33 – Manufacturing          31
# 538                         Sector 42 – Wholesale Trade          42
# 614                       Sector 44 - 45 – Retail Trade          44
# 694     Sector 48 - 49 – Transportation and Warehousing          48
# 764                             Sector 51 – Information          51
# 802                   Sector 52 – Finance and Insurance          52
# 847      Sector 53 – Real Estate and Rental and Leasing          53
# 875   Sector 54 – Professional, Scientific and Techn...          54
# 932   Sector 55 – Management of Companies and Enterp...          55
# 936   Sector 56 – Administrative and Support and Was...          56
# 984                    Sector 61 – Educational Services          61
# 1004      Sector 62 – Health Care and Social Assistance          62
# 1048     Sector 71 – Arts, Entertainment and Recreation          71
# 1077        Sector 72 – Accommodation and Food Services          72
# 1095                         Sector 81 – Other Services          81
# 1147                  Sector 92 – Public Administration          92
#
#                                                  Sector
# 0            Agriculture, Forestry, Fishing and Hunting
# 71        Mining, Quarrying, and Oil and Gas Extraction
# 103                                           Utilities
# 119                                        Construction
# 156                                       Manufacturing
# 538                                     Wholesale Trade
# 614                                        Retail Trade
# 694                      Transportation and Warehousing
# 764                                         Information
# 802                               Finance and Insurance
# 847                  Real Estate and Rental and Leasing
# 875     Professional, Scientific and Technical Services
# 932             Management of Companies and Enterprises
# 936   Administrative and Support and Waste Managemen...
# 984                                Educational Services
# 1004                  Health Care and Social Assistance
# 1048                 Arts, Entertainment and Recreation
# 1077                    Accommodation and Food Services
# 1095                                     Other Services
# 1147                              Public Administration

# %%
#2 methods to append values
#method 1
data.loc[len(data.index)] = ['Sector 48 - 49 – Transportation and Warehousing',49,'Transportation and Warehousing']
data.loc[len(data.index)] = ['Sector 31 – 33 – Manufacturing',32,'TManufacturing']
data.loc[len(data.index)] = ['Sector 31 – 33 – Manufacturing',33,'TManufacturing']

#method2
df2 = {'NAICS Industry Description': 'Sector 44 - 45 – Retail Trade','LookupCodes': 45,'Sector': 'Retail Trade'}

data = data.append(df2, ignore_index = True)

# %%
data
# Out:
#                            NAICS Industry Description LookupCodes  \
# 0   Sector 11 – Agriculture, Forestry, Fishing and...          11
# 1   Sector 21 – Mining, Quarrying, and Oil and Gas...          21
# 2                               Sector 22 – Utilities          22
# 3                            Sector 23 – Construction          23
# 4                      Sector 31 – 33 – Manufacturing          31
# 5                         Sector 42 – Wholesale Trade          42
# 6                       Sector 44 - 45 – Retail Trade          44
# 7     Sector 48 - 49 – Transportation and Warehousing          48
# 8                             Sector 51 – Information          51
# 9                   Sector 52 – Finance and Insurance          52
# 10     Sector 53 – Real Estate and Rental and Leasing          53
# 11  Sector 54 – Professional, Scientific and Techn...          54
# 12  Sector 55 – Management of Companies and Enterp...          55
# 13  Sector 56 – Administrative and Support and Was...          56
# 14                   Sector 61 – Educational Services          61
# 15      Sector 62 – Health Care and Social Assistance          62
# 16     Sector 71 – Arts, Entertainment and Recreation          71
# 17        Sector 72 – Accommodation and Food Services          72
# 18                         Sector 81 – Other Services          81
# 19                  Sector 92 – Public Administration          92
# 20    Sector 48 - 49 – Transportation and Warehousing          49
# 21                     Sector 31 – 33 – Manufacturing          32
# 22                     Sector 31 – 33 – Manufacturing          33
# 23                      Sector 44 - 45 – Retail Trade          45
#
#                                                Sector
# 0          Agriculture, Forestry, Fishing and Hunting
# 1       Mining, Quarrying, and Oil and Gas Extraction
# 2                                           Utilities
# 3                                        Construction
# 4                                       Manufacturing
# 5                                     Wholesale Trade
# 6                                        Retail Trade
# 7                      Transportation and Warehousing
# 8                                         Information
# 9                               Finance and Insurance
# 10                 Real Estate and Rental and Leasing
# 11    Professional, Scientific and Technical Services
# 12            Management of Companies and Enterprises
# 13  Administrative and Support and Waste Managemen...
# 14                               Educational Services
# 15                  Health Care and Social Assistance
# 16                 Arts, Entertainment and Recreation
# 17                    Accommodation and Food Services
# 18                                     Other Services
# 19                              Public Administration
# 20                     Transportation and Warehousing
# 21                                     TManufacturing
# 22                                     TManufacturing
# 23                                       Retail Trade

# %%
#Save data to csv 
data.to_csv('clean_data.csv', encoding = 'utf-8')

# %%
#Save data to csv 
data.to_csv('clean_data.csv', encoding = 'utf-8', index = False)
