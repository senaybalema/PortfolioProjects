# %%
# import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# import data

# %%
data = pd.read_csv(r"C:\Users\senay\Desktop\Misra Turp\NYC_Jobs.csv")
data.head()
# Out:
#    Job ID             Civil Service Title                         Agency  \
# 0  424339             PUBLIC HEALTH NURSE  DEPT OF HEALTH/MENTAL HYGIENE
# 1  379094         CERT IT DEVELOPER (APP)   NYC EMPLOYEES RETIREMENT SYS
# 2  520417        EXECUTIVE AGENCY COUNSEL          NYC HOUSING AUTHORITY
# 3  233549  CERTIFIED IT ADMINISTRATOR (LA   NYC EMPLOYEES RETIREMENT SYS
# 4  510256  ASSOCIATE HUMAN RIGHTS SPECIAL        HUMAN RIGHTS COMMISSION
#
#   Posting Type                                 Job Category  \
# 0     External                                       Health
# 1     External                                          NaN
# 2     External                                Legal Affairs
# 3     External  Information Technology & Telecommunications
# 4     External    Constituent Services & Community Programs
#
#    Salary Range From  Salary Range To
# 0            84252.0          84252.0
# 1            82884.0         116391.0
# 2           105000.0         125000.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3773 entries, 0 to 3772
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Job ID               3773 non-null   int64
#  1   Civil Service Title  3773 non-null   object
#  2   Agency               3773 non-null   object
#  3   Posting Type         3773 non-null   object
#  4   Job Category         3770 non-null   object
#  5   Salary Range From    3773 non-null   float64
#  6   Salary Range To      3773 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 206.5+ KB

# %%
df = pd.DataFrame({'foo': ['one', 'one', 'one','two', 'two','two'],
                   'bar': ['A', 'B','C','A','B','C'],
                   'baz': [1,2,3,4,5,6],
                   'zoo': ['x','y','z','q','w','t']

})
df
# Out:
#    foo bar  baz zoo
# 0  one   A    1   x
# 1  one   B    2   y
# 2  one   C    3   z
# 3  two   A    4   q
# 4  two   B    5   w
# 5  two   C    6   t

# %% [markdown]
# #### pivot

# %%
df.pivot(index='foo', columns='bar', values='baz')
# Out:
# bar  A  B  C
# foo
# one  1  2  3
# two  4  5  6

# %%
df.pivot(values='baz', index=['foo', 'bar'], columns=['zoo'])
# Out:
# zoo        q    t    w    x    y    z
# foo bar
# one A    NaN  NaN  NaN  1.0  NaN  NaN
#     B    NaN  NaN  NaN  NaN  2.0  NaN
#     C    NaN  NaN  NaN  NaN  NaN  3.0
# two A    4.0  NaN  NaN  NaN  NaN  NaN
#     B    NaN  NaN  5.0  NaN  NaN  NaN
#     C    NaN  6.0  NaN  NaN  NaN  NaN

# %%
data.columns
# Out:
# Index(['Job ID', 'Civil Service Title', 'Agency', 'Posting Type',
#        'Job Category', 'Salary Range From', 'Salary Range To'],
#       dtype='object')

# %%
data.shape
# Out:
# (3773, 7)

# %%
data.pivot(values='Salary Range From', index='Job ID', columns='Agency')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data.pivot(values='Salary Range From', index='Job ID', columns='Agency')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:7793, in DataFrame.pivot(self, index, columns, values)
#    7788 @Substitution("")
#    7789 @Appender(_shared_docs["pivot"])
#    7790 def pivot(self, index=None, columns=None, values=None) -> DataFrame:
#    7791     from pandas.core.reshape.pivot import pivot
# -> 7793     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:517, in pivot(data, index, columns, values)
#     515     else:
#     516         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517 return indexed.unstack(columns_listlike)
#
# ...

# %%
data.pivot_table(values='Salary Range From', index='Job ID', columns='Agency')
# Out:
# Agency  ADMIN FOR CHILDREN'S SVCS  ADMIN TRIALS AND HEARINGS  \
# Job ID
# 87990                         NaN                        NaN
# 97899                         NaN                        NaN
# 137433                        NaN                        NaN
# 152738                        NaN                        NaN
# 167179                        NaN                        NaN
# ...                           ...                        ...
# 528407                        NaN                        NaN
# 528433                        NaN                        NaN
# 528445                        NaN                        NaN
# 528522                        NaN                        NaN
# 528532                        NaN                        NaN
#
# Agency  BOARD OF CORRECTION  BOROUGH PRESIDENT-QUEENS  \
# Job ID
# 87990                   NaN                       NaN
# 97899                   NaN                       NaN
# ...

# %%
data.pivot_table(values='Salary Range From', index='Job ID', columns='Agency').shape
# Out:
# (2073, 56)

# %% [markdown]
# #### stacked

# %%
tuples = list(
    zip(
        *[
            ["bar","bar","baz","baz","foo","foo","qux","qux"],
            ["one","two","one","two","one","two","one","two"] 
        ]
  
    )
)

tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=["first","second"])
df = pd.DataFrame(np.random.randn(8,2), index=index, columns = ["A","B"])
df
# Out:
#                      A         B
# first second
# bar   one    -1.847706  0.385399
#       two    -0.501216 -0.407316
# baz   one    -0.004134 -0.382887
#       two    -0.064365  1.050391
# foo   one    -0.379602  2.297629
#       two     0.058892  0.467699
# qux   one    -0.224662  0.716414
#       two    -0.773509  0.566093

# %%
df[:4]
# Out:
#                      A         B
# first second
# bar   one    -1.847706  0.385399
#       two    -0.501216 -0.407316
# baz   one    -0.004134 -0.382887
#       two    -0.064365  1.050391

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -1.847706  0.385399
#       two    -0.501216 -0.407316
# baz   one    -0.004134 -0.382887
#       two    -0.064365  1.050391

# %%
df2.stack()
# Out:
# first  second
# bar    one     A   -1.847706
#                B    0.385399
#        two     A   -0.501216
#                B   -0.407316
# baz    one     A   -0.004134
#                B   -0.382887
#        two     A   -0.064365
#                B    1.050391
# dtype: float64

# %%
pd.DataFrame(df2.stack())
# Out:
#                        0
# first second
# bar   one    A -1.847706
#              B  0.385399
#       two    A -0.501216
#              B -0.407316
# baz   one    A -0.004134
#              B -0.382887
#       two    A -0.064365
#              B  1.050391

# %%
stacked_df = pd.DataFrame(df2.stack())
stacked_df
# Out:
#                        0
# first second
# bar   one    A -1.847706
#              B  0.385399
#       two    A -0.501216
#              B -0.407316
# baz   one    A -0.004134
#              B -0.382887
#       two    A -0.064365
#              B  1.050391

# %%
stacked_df.unstack
# Out:
# <bound method DataFrame.unstack of                        0
# first second
# bar   one    A -1.847706
#              B  0.385399
#       two    A -0.501216
#              B -0.407316
# baz   one    A -0.004134
#              B -0.382887
#       two    A -0.064365
#              B  1.050391>

# %%
stacked_df.unstack('second')
# Out:
#                 0
# second        one       two
# first
# bar   A -1.847706 -0.501216
#       B  0.385399 -0.407316
# baz   A -0.004134 -0.064365
#       B -0.382887  1.050391

# %% [markdown]
# #### melt

# %%
pd.melt(data, id_vars='Job ID', value_vars=['Agency','Posting Type'])
# Out:
#       Job ID      variable                          value
# 0     424339        Agency  DEPT OF HEALTH/MENTAL HYGIENE
# 1     379094        Agency   NYC EMPLOYEES RETIREMENT SYS
# 2     520417        Agency          NYC HOUSING AUTHORITY
# 3     233549        Agency   NYC EMPLOYEES RETIREMENT SYS
# 4     510256        Agency        HUMAN RIGHTS COMMISSION
# ...      ...           ...                            ...
# 7541  457839  Posting Type                       Internal
# 7542  527141  Posting Type                       Internal
# 7543  509443  Posting Type                       Internal
# 7544  352367  Posting Type                       Internal
# 7545  478739  Posting Type                       External
#
# [7546 rows x 3 columns]

# %%
melted_df=pd.melt(data, id_vars='Job ID', value_vars=['Agency','Posting Type'])

# %%
melted_df[melted_df['Job ID']==510670]
# Out:
#       Job ID      variable                          value
# 3535  510670        Agency  OFF OF PAYROLL ADMINISTRATION
# 7308  510670  Posting Type                       Internal

# %%
data.groupby('Agency').mean()
# Out:
#                                        Job ID  Salary Range From  \
# Agency
# ADMIN FOR CHILDREN'S SVCS       460844.450000       59864.200000
# ADMIN TRIALS AND HEARINGS       514536.625000       63196.562500
# BOARD OF CORRECTION             527087.666667      108033.333333
# BOROUGH PRESIDENT-QUEENS        527260.000000       51860.500000
# BUSINESS INTEGRITY COMMISSION   413144.777778       67923.222222
# CAMPAIGN FINANCE BOARD          524621.000000       65000.000000
# CIVIL SERVICE COMMISSION        519541.000000       62397.000000
# CIVILIAN COMPLAINT REVIEW BD    493279.307692       54816.307692
# CONFLICTS OF INTEREST BOARD     519630.000000       67443.500000
# CONSUMER AND WORKER PROTECTION  524301.447368       53082.921053
# DEPARTMENT FOR THE AGING        512997.600000       46621.869520
# DEPARTMENT OF BUILDINGS         527396.046512       21621.566515
# DEPARTMENT OF BUSINESS SERV.    465332.000000       68203.600000
# ...

# %%
data[['Agency','Salary Range From']].groupby('Agency').mean()
# Out:
#                                 Salary Range From
# Agency
# ADMIN FOR CHILDREN'S SVCS            59864.200000
# ADMIN TRIALS AND HEARINGS            63196.562500
# BOARD OF CORRECTION                 108033.333333
# BOROUGH PRESIDENT-QUEENS             51860.500000
# BUSINESS INTEGRITY COMMISSION        67923.222222
# CAMPAIGN FINANCE BOARD               65000.000000
# CIVIL SERVICE COMMISSION             62397.000000
# CIVILIAN COMPLAINT REVIEW BD         54816.307692
# CONFLICTS OF INTEREST BOARD          67443.500000
# CONSUMER AND WORKER PROTECTION       53082.921053
# DEPARTMENT FOR THE AGING             46621.869520
# DEPARTMENT OF BUILDINGS              21621.566515
# DEPARTMENT OF BUSINESS SERV.         68203.600000
# DEPARTMENT OF CITY PLANNING          31639.108434
# DEPARTMENT OF CORRECTION             85941.592606
# DEPARTMENT OF FINANCE                65943.264242
# DEPARTMENT OF INVESTIGATION          74024.500000
# DEPARTMENT OF PROBATION              28517.991250
# ...

# %% [markdown]
# #### crosstab

# %%
pd.crosstab(data['Agency'],data['Posting Type'])
# Out:
# Posting Type                    External  Internal
# Agency
# ADMIN FOR CHILDREN'S SVCS             12        28
# ADMIN TRIALS AND HEARINGS             16        16
# BOARD OF CORRECTION                    3         3
# BOROUGH PRESIDENT-QUEENS               2         2
# BUSINESS INTEGRITY COMMISSION          5         4
# CAMPAIGN FINANCE BOARD                 1         1
# CIVIL SERVICE COMMISSION               1         1
# CIVILIAN COMPLAINT REVIEW BD           5         8
# CONFLICTS OF INTEREST BOARD            2         2
# CONSUMER AND WORKER PROTECTION        38        38
# DEPARTMENT FOR THE AGING              10        10
# DEPARTMENT OF BUILDINGS               39        47
# DEPARTMENT OF BUSINESS SERV.           6         9
# DEPARTMENT OF CITY PLANNING           40        43
# DEPARTMENT OF CORRECTION             102       111
# DEPARTMENT OF FINANCE                 11        22
# DEPARTMENT OF INVESTIGATION           13        15
# ...

# %% [markdown]
# #### explode

# %%
keys = ["panda1",'panda2','panda3']

values = [["eats", "shoots"], ["shoots", "leaves"],["eats","leaves"]]

df=pd.DataFrame({'keys': keys, 'values':values})

df
# Out:
#      keys            values
# 0  panda1    [eats, shoots]
# 1  panda2  [shoots, leaves]
# 2  panda3    [eats, leaves]

# %%
df.explode('values')
# Out:
#      keys  values
# 0  panda1    eats
# 0  panda1  shoots
# 1  panda2  shoots
# 1  panda2  leaves
# 2  panda3    eats
# 2  panda3  leaves

# %%
df['values'].explode()
# Out:
# 0      eats
# 0    shoots
# 1    shoots
# 1    leaves
# 2      eats
# 2    leaves
# Name: values, dtype: object

# %%
s= df['values'].explode()

# %%
s.dtypes
# Out:
# dtype('O')

# %%
isinstance(s,pd. DataFrame)
# Out:
# False

# %%
s.to_frame()
# Out:
#    values
# 0    eats
# 0  shoots
# 1  shoots
# 1  leaves
# 2    eats
# 2  leaves
