# %%
import pandas as pd

# %%
titanic = pd.read_csv(r'C:\Users\senay\Desktop\Misra Turp\titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Extracting Parts of the dataframe

# %%
titanic[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
titanic[titanic['Age']>30]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 881          882         0       3
# 885          886         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[(titanic['Age']>30) & (titanic['Fare']> 50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 35            36         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 838          839         1       3
# 856          857         1       1
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic['Pclass'].isin(['1','3'])]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
titanic[~titanic['Pclass'].isin(['1','3'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic[titanic['Age']==30]
# Out:
#      PassengerId  Survived  Pclass  \
# 79            80         1       3
# 157          158         0       3
# 178          179         0       2
# 213          214         0       2
# 219          220         0       2
# 244          245         0       3
# 253          254         0       3
# 257          258         1       1
# 286          287         1       3
# 308          309         0       2
# 309          310         1       1
# 322          323         1       2
# 365          366         0       3
# 418          419         0       2
# 452          453         0       1
# 488          489         0       3
# 520          521         1       1
# 534          535         0       3
# 537          538         1       1
# 606          607         0       3
# 726          727         1       2
# 747          748         1       2
# 798          799         0       3
# 799          800         0       3
# 842          843         1       1
#
# ...

# %% [markdown]
# # Alterations on the dataframe

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#change tcolumn name
titanic.rename(columns={"SibSp": "Siblings/Spouses Abroad", "Parch": "Parents/Children Aboard"},inplace=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age',
#        'Siblings/Spouses Abroad', 'Parents/Children Aboard', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %%
#adding new column
titanic['Total fare paid by family'] = (titanic['Siblings/Spouses Abroad'] + titanic['Parents/Children Aboard'] + 1) * titanic['Fare']
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
# change column name
titanic.rename(columns = {"Fare": "Ticket Fee", "Survived": ":)"})
# Out:
#      PassengerId  :)  Pclass  \
# 0              1   0       3
# 1              2   1       1
# 2              3   1       3
# 3              4   1       1
# 4              5   0       3
# ..           ...  ..     ...
# 886          887   0       2
# 887          888   1       1
# 888          889   0       3
# 889          890   1       1
# 890          891   0       3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# ...

# %%
#reset_index 
filtered_titanic = titanic[titanic['Age']==30].reset_index()
filtered_titanic
# Out:
#     index  PassengerId  Survived  Pclass  \
# 0      79           80         1       3
# 1     157          158         0       3
# 2     178          179         0       2
# 3     213          214         0       2
# 4     219          220         0       2
# 5     244          245         0       3
# 6     253          254         0       3
# 7     257          258         1       1
# 8     286          287         1       3
# 9     308          309         0       2
# 10    309          310         1       1
# 11    322          323         1       2
# 12    365          366         0       3
# 13    418          419         0       2
# 14    452          453         0       1
# 15    488          489         0       3
# 16    520          521         1       1
# 17    534          535         0       3
# 18    537          538         1       1
# 19    606          607         0       3
# 20    726          727         1       2
# 21    747          748         1       2
# ...

# %%
filtered_titanic = titanic[titanic['Age']==30].reset_index(drop=True)
filtered_titanic
# Out:
#     PassengerId  Survived  Pclass  \
# 0            80         1       3
# 1           158         0       3
# 2           179         0       2
# 3           214         0       2
# 4           220         0       2
# 5           245         0       3
# 6           254         0       3
# 7           258         1       1
# 8           287         1       3
# 9           309         0       2
# 10          310         1       1
# 11          323         1       2
# 12          366         0       3
# 13          419         0       2
# 14          453         0       1
# 15          489         0       3
# 16          521         1       1
# 17          535         0       3
# 18          538         1       1
# 19          607         0       3
# 20          727         1       2
# 21          748         1       2
# 22          799         0       3
# 23          800         0       3
# 24          843         1       1
#
# ...

# %%
#sort_values
titanic.sort_values(by ='Fare', ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  Siblings/Spouses Abroad  Parents/Children Aboard    Ticket  \
# ...

# %%
#lower
titanic['Name'] = titanic['Name'].str.lower()
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  \
# 0                              braund, mr. owen harris    male  22.0
# 1    cumings, mrs. john bradley (florence briggs th...  female  38.0
# 2                               heikkinen, miss. laina  female  26.0
# 3         futrelle, mrs. jacques heath (lily may peel)  female  35.0
# 4                             allen, mr. william henry    male  35.0
# ..                                                 ...     ...   ...
# ...

# %%
#who is a reverend 
titanic[titanic['Name'].str.contains("rev. ")]
# Out:
#      PassengerId  Survived  Pclass                               Name   Sex  \
# 149          150         0       2  byles, rev. thomas roussel davids  male
# 150          151         0       2         bateman, rev. robert james  male
# 249          250         0       2      carter, rev. ernest courtenay  male
# 626          627         0       2     kirkland, rev. charles leonard  male
# 848          849         0       2                  harper, rev. john  male
# 886          887         0       2              montvila, rev. juozas  male
#
#       Age  Siblings/Spouses Abroad  Parents/Children Aboard       Ticket  \
# 149  42.0                        0                        0       244310
# 150  51.0                        0                        0  S.O.P. 1166
# 249  54.0                        1                        0       244252
# 626  57.0                        0                        0       219533
# ...

# %%
titanic = pd.read_csv(r'C:\Users\senay\Desktop\Misra Turp\titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#add new rows
data_to_add = {"Survived": [1,0], "Pclass":[1,3], "Name":["Miss. Rose Dewitt Bukater", "Mr. Jack Dawson"], "Sex":["female", "male"]
              ,"Age" : [17,20], "SibSp":[2,0], "Parch":[0,0], "Fare":[49.5042, 19.2583]}
addendum = pd.DataFrame(columns = titanic.columns, data = data_to_add)
addendum
# Out:
#   PassengerId  Survived  Pclass                       Name     Sex  Age  \
# 0         NaN         1       1  Miss. Rose Dewitt Bukater  female   17
# 1         NaN         0       3            Mr. Jack Dawson    male   20
#
#    SibSp  Parch Ticket     Fare Cabin Embarked
# 0      2      0    NaN  49.5042   NaN      NaN
# 1      0      0    NaN  19.2583   NaN      NaN

# %%
addendum = addendum[['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare']]
addendum
# Out:
#    Survived  Pclass                       Name     Sex  Age  SibSp  Parch  \
# 0         1       1  Miss. Rose Dewitt Bukater  female   17      2      0
# 1         0       3            Mr. Jack Dawson    male   20      0      0
#
#   Ticket     Fare
# 0    NaN  49.5042
# 1    NaN  19.2583

# %%
titanic = pd.read_csv(r'C:\Users\senay\Desktop\Misra Turp\titanic.csv')

titanic = titanic[['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare']]
titanic
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare
# ...

# %%
#concat
pd.concat([titanic, addendum])
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
# 0           1       1                          Miss. Rose Dewitt Bukater
# 1           0       3                                    Mr. Jack Dawson
#
#         Sex   Age  SibSp  Parch            Ticket     Fare
# ...

# %%
#merge 
data_to_add = {"Pclass":[1,2,3], "Total cabin amount":[371, 105, 84]}
extra_info = pd.DataFrame(columns = ['Pclass', 'Total cabin amount'], data = data_to_add)
extra_info
# Out:
#    Pclass  Total cabin amount
# 0       1                 371
# 1       2                 105
# 2       3                  84

# %%
titanic.merge(extra_info, how = 'left', on='Pclass')
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare  Total cabin amount
# ...

# %% [markdown]
# # Aggregations

# %%
#describe
titanic.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic['Age'].mean()
# Out:
# 29.69911764705882

# %%
titanic['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
#groupby
titanic.groupby('Sex')['Age'].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.groupby('Sex')['Age'].count()
# Out:
# Sex
# female    261
# male      453
# Name: Age, dtype: int64

# %% [markdown]
# # Plotting

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
titanic['Age'].plot()
# Out:
# <Axes: >

# %%
titanic[['Age','Survived']].plot(x='Age', y='Survived', kind='scatter', figsize=(20,10))
# Out:
# C:\Users\senay\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1070: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Age', ylabel='Survived'>

# %%
titanic.hist(figsize=(20,10), bins=100)
# Out:
# array([[<Axes: title={'center': 'Survived'}>,
#         <Axes: title={'center': 'Pclass'}>],
#        [<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'SibSp'}>],
#        [<Axes: title={'center': 'Parch'}>,
#         <Axes: title={'center': 'Fare'}>]], dtype=object)
